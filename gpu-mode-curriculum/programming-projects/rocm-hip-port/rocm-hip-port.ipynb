# %% [markdown]
# # ROCm/HIP portability: ROCm/HIP portability path
#
# Query: `rocm hip cuda portability wmma`
#
# Suspect CUDA-specific runtime calls, warp-size assumptions, WMMA/Tensor Core dependencies, or missing ROCm compiler/runtime support.

# %% [markdown]
# ## Read First
#
# - AMD ROCm: [HIP Documentation](https://rocm.docs.amd.com/projects/HIP/en/latest/)
# - AMD ROCm: [Introduction to the HIP Programming Model](https://rocm.docs.amd.com/projects/HIP/en/latest/understand/programming_model.html)

# %% [markdown]
# ## GPUMODE Anchors
#
# - Lesson 80: [Lecture 36: CUTLASS and Flash Attention 3](https://www.youtube.com/watch?v=JwUcZwPOCpA)
# - Lesson 57: [Lecture 57: CuTe](https://www.youtube.com/watch?v=vzUhbDO_0qk)
# - Lesson 70: [Lecture 46: Distributed GEMM](https://www.youtube.com/watch?v=NHRTCQBZokg)
# - Lesson 95: [Lecture 23: Tensor Cores](https://www.youtube.com/watch?v=hQ9GPnV0-50)
# - Lesson 115: [Lecture 4 Compute and Memory Basics](https://www.youtube.com/watch?v=lTmYrKwjSOU)

# %% [markdown]
# ## Project Tasks
#
# - `read-source-model` (reading): Read AMD ROCm - HIP Documentation and record the bottleneck model.
# - `anchor-gpumode-lesson` (lesson): Use GPUMODE lesson 80: Lecture 36: CUTLASS and Flash Attention 3 as the concept anchor.
# - `modify-starter-source` (programming): Modify `kernel.hip.cpp` and keep `python3 starter.py` runnable.
# - `run-local-measurement` (measurement): Run `python3 measure.py` and preserve `measurements.json`.
# - `compare-existing-lab` (comparison): Compare against `gpu-kernels-serving-lab/25-gpumode-rocm-hip-portability` and `25-gpumode-rocm-hip-portability/out_gpumode_rocm_hip_portability.json`.

# %%
from pathlib import Path
import json

HERE = Path.cwd()
print("project dir:", HERE)
print(json.dumps(json.loads(Path("project.json").read_text()), indent=2)[:1200])

# %%
import subprocess, sys

proc = subprocess.run([sys.executable, "starter.py"], capture_output=True, text=True)
print(proc.stdout)
print(proc.stderr)
assert proc.returncode == 0

# %%
import subprocess, sys, json
from pathlib import Path

proc = subprocess.run([sys.executable, "measure.py"], capture_output=True, text=True)
print(proc.stdout)
print(proc.stderr)
assert proc.returncode == 0
measurement = json.loads(Path("measurements.json").read_text())
assert measurement["correctness"]["status"] == "passed"
measurement

# %% [markdown]
# ## Latest Local Evidence
#
# - Status: `source-only`
# - Correctness: `passed`
# - Baseline lab artifact: `25-gpumode-rocm-hip-portability/out_gpumode_rocm_hip_portability.json`
