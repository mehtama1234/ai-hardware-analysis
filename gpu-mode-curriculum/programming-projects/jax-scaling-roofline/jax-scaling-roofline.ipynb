# %% [markdown]
# # JAX scaling and roofline: Memory bandwidth / layout bottleneck
#
# Query: `jax scaling roofline gpu hbm inference`
#
# Suspect memory layout, HBM bandwidth, KV-cache growth, or avoidable materialization before changing math.

# %% [markdown]
# ## Read First
#
# - JAX Scaling Book: [All About Rooflines](https://jax-ml.github.io/scaling-book/roofline/)
# - JAX Scaling Book: [All About Transformer Inference](https://jax-ml.github.io/scaling-book/inference/)
# - JAX Scaling Book: [How to Think About GPUs](https://jax-ml.github.io/scaling-book/gpus/)
# - NVIDIA: [CUDA C++ Best Practices Guide](https://docs.nvidia.com/cuda/cuda-c-best-practices-guide/index.html)
# - NVIDIA: [CUDA C++ Programming Guide](https://docs.nvidia.com/cuda/cuda-programming-guide/index.html)

# %% [markdown]
# ## GPUMODE Anchors
#
# - Lesson 115: [Lecture 4 Compute and Memory Basics](https://www.youtube.com/watch?v=lTmYrKwjSOU)
# - Lesson 2: [Lecture 112: Production Megakernels for Real-World Inference](https://www.youtube.com/watch?v=loZ4xQ5RZuU)
# - Lesson 17: [Lecture 97: HipKittens](https://www.youtube.com/watch?v=jsYyF03Fs3o)
# - Lesson 16: [Lecture 98: GPU Observability](https://www.youtube.com/watch?v=-6FlMJ-AP74)
# - Lesson 34: [Lecture 80: How FlashAttention 4 Works](https://www.youtube.com/watch?v=VPslgC9piIw)

# %% [markdown]
# ## Project Tasks
#
# - `read-source-model` (reading): Read JAX Scaling Book - All About Rooflines and record the bottleneck model.
# - `anchor-gpumode-lesson` (lesson): Use GPUMODE lesson 115: Lecture 4 Compute and Memory Basics as the concept anchor.
# - `modify-starter-source` (programming): Modify `roofline_model.py` and keep `python3 starter.py` runnable.
# - `run-local-measurement` (measurement): Run `python3 measure.py` and preserve `measurements.json`.
# - `compare-existing-lab` (comparison): Compare against `gpu-kernels-serving-lab/23-gpumode-shared-memory-gemm` and `23-gpumode-shared-memory-gemm/out_gpumode_shared_memory_gemm.json`.

# %%
from pathlib import Path
import json

HERE = Path.cwd()
print("project dir:", HERE)
print(json.dumps(json.loads(Path("project.json").read_text()), indent=2)[:1200])

# %%
import subprocess, sys

proc = subprocess.run([sys.executable, "starter.py"], capture_output=True, text=True)
print(proc.stdout)
print(proc.stderr)
assert proc.returncode == 0

# %%
import subprocess, sys, json
from pathlib import Path

proc = subprocess.run([sys.executable, "measure.py"], capture_output=True, text=True)
print(proc.stdout)
print(proc.stderr)
assert proc.returncode == 0
measurement = json.loads(Path("measurements.json").read_text())
assert measurement["correctness"]["status"] == "passed"
measurement

# %% [markdown]
# ## Latest Local Evidence
#
# - Status: `ran`
# - Correctness: `passed`
# - Baseline lab artifact: `23-gpumode-shared-memory-gemm/out_gpumode_shared_memory_gemm.json`
