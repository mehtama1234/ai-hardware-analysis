# %% [markdown]
# # Triton kernels: Triton custom-kernel / autotuning path
#
# Query: `triton fused softmax autotune`
#
# Suspect block sizes, masks, fusion boundaries, or compiler-generated kernel choices.

# %% [markdown]
# ## Read First
#
# - Triton: [Triton Tutorials](https://triton-lang.org/main/getting-started/tutorials/)
# - Triton: [Fused Softmax Tutorial](https://triton-lang.org/main/getting-started/tutorials/02-fused-softmax.html)
# - NVIDIA: [CUDA C++ Programming Guide](https://docs.nvidia.com/cuda/cuda-programming-guide/index.html)
# - AMD ROCm: [Introduction to the HIP Programming Model](https://rocm.docs.amd.com/projects/HIP/en/latest/understand/programming_model.html)

# %% [markdown]
# ## GPUMODE Anchors
#
# - Lesson 13: [Lecture 101: Learning CUTLASS the hard way](https://www.youtube.com/watch?v=jGouxuAHIfQ)
# - Lesson 26: [Lecture 89: cuTile (from friends at NVIDIA)](https://www.youtube.com/watch?v=_b4I4rKpsGA)
# - Lesson 35: [Lecture 79 Mirage (MPK): Compiling LLMs into Mega Kernels](https://www.youtube.com/watch?v=sXDdRCy137c)
# - Lesson 39: [Lecture 75 [ScaleML Series] GPU Programming Fundamentals + ThunderKittens](https://www.youtube.com/watch?v=Cl2B_hmg4gA)
# - Lesson 59: [Lecture 55: Modular’s unified device accelerator language](https://www.youtube.com/watch?v=5gPG7SXoBag)

# %% [markdown]
# ## Project Tasks
#
# - `read-source-model` (reading): Read Triton - Triton Tutorials and record the bottleneck model.
# - `anchor-gpumode-lesson` (lesson): Use GPUMODE lesson 13: Lecture 101: Learning CUTLASS the hard way as the concept anchor.
# - `modify-starter-source` (programming): Modify `kernel.py` and keep `python3 starter.py` runnable.
# - `run-local-measurement` (measurement): Run `python3 measure.py` and preserve `measurements.json`.
# - `compare-existing-lab` (comparison): Compare against `gpu-kernels-serving-lab/17-gpumode-triton-autotune` and `23-gpumode-shared-memory-gemm/out_gpumode_shared_memory_gemm.json`.

# %%
from pathlib import Path
import json

HERE = Path.cwd()
print("project dir:", HERE)
print(json.dumps(json.loads(Path("project.json").read_text()), indent=2)[:1200])

# %%
import subprocess, sys

proc = subprocess.run([sys.executable, "starter.py"], capture_output=True, text=True)
print(proc.stdout)
print(proc.stderr)
assert proc.returncode == 0

# %%
import subprocess, sys, json
from pathlib import Path

proc = subprocess.run([sys.executable, "measure.py"], capture_output=True, text=True)
print(proc.stdout)
print(proc.stderr)
assert proc.returncode == 0
measurement = json.loads(Path("measurements.json").read_text())
assert measurement["correctness"]["status"] == "passed"
measurement

# %% [markdown]
# ## Latest Local Evidence
#
# - Status: `ran`
# - Correctness: `passed`
# - Baseline lab artifact: `23-gpumode-shared-memory-gemm/out_gpumode_shared_memory_gemm.json`
