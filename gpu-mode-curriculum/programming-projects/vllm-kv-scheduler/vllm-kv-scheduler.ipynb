# %% [markdown]
# # vLLM-style serving: vLLM scheduler / TTFT and batching bottleneck
#
# Query: `vllm scheduler kv cache ttft batching`
#
# Suspect batching policy, chunked prefill, prefix-cache reuse, admission control, or SLA-driven decode scheduling.

# %% [markdown]
# ## Read First
#
# - JAX Scaling Book: [All About Transformer Inference](https://jax-ml.github.io/scaling-book/inference/)
# - Hugging Face: [LLM Course: Optimized Inference Deployment](https://huggingface.co/learn/llm-course/chapter2/8)
# - Hugging Face: [Text Generation Inference Documentation](https://huggingface.co/docs/text-generation-inference/index)
# - JAX Scaling Book: [Serving LLaMA 3-70B on TPUs](https://jax-ml.github.io/scaling-book/applied-inference/)
# - Hugging Face: [Transformers: Causal Language Modeling](https://huggingface.co/docs/transformers/en/tasks/language_modeling)

# %% [markdown]
# ## GPUMODE Anchors
#
# - Lesson 14: [Lecture 100: InferenceX Continuous OSS Inference Benchmarking](https://www.youtube.com/watch?v=kPBTBl7xvEY)
# - Lesson 16: [Lecture 98: GPU Observability](https://www.youtube.com/watch?v=-6FlMJ-AP74)
# - Lesson 88: [GPU MODE IRL 2024 Keynotes](https://www.youtube.com/watch?v=FH5wiwOyPX4)
# - Lesson 2: [Lecture 112: Production Megakernels for Real-World Inference](https://www.youtube.com/watch?v=loZ4xQ5RZuU)
# - Lesson 17: [Lecture 97: HipKittens](https://www.youtube.com/watch?v=jsYyF03Fs3o)

# %% [markdown]
# ## Project Tasks
#
# - `read-source-model` (reading): Read JAX Scaling Book - All About Transformer Inference and record the bottleneck model.
# - `anchor-gpumode-lesson` (lesson): Use GPUMODE lesson 14: Lecture 100: InferenceX Continuous OSS Inference Benchmarking as the concept anchor.
# - `modify-starter-source` (programming): Modify `scheduler.py` and keep `python3 starter.py` runnable.
# - `run-local-measurement` (measurement): Run `python3 measure.py` and preserve `measurements.json`.
# - `compare-existing-lab` (comparison): Compare against `gpu-kernels-serving-lab/20-gpumode-vllm-scheduler` and `20-gpumode-vllm-scheduler/out_gpumode_vllm_scheduler.json`.

# %%
from pathlib import Path
import json

HERE = Path.cwd()
print("project dir:", HERE)
print(json.dumps(json.loads(Path("project.json").read_text()), indent=2)[:1200])

# %%
import subprocess, sys

proc = subprocess.run([sys.executable, "starter.py"], capture_output=True, text=True)
print(proc.stdout)
print(proc.stderr)
assert proc.returncode == 0

# %%
import subprocess, sys, json
from pathlib import Path

proc = subprocess.run([sys.executable, "measure.py"], capture_output=True, text=True)
print(proc.stdout)
print(proc.stderr)
assert proc.returncode == 0
measurement = json.loads(Path("measurements.json").read_text())
assert measurement["correctness"]["status"] == "passed"
measurement

# %% [markdown]
# ## Latest Local Evidence
#
# - Status: `ran`
# - Correctness: `passed`
# - Baseline lab artifact: `20-gpumode-vllm-scheduler/out_gpumode_vllm_scheduler.json`
