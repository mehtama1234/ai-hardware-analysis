# %% [markdown]
# # Profiler-to-roofline evidence: Profiler counters / roofline triage
#
# Query: `nsight roofline dram sm stall counters`
#
# Suspect the next optimization is unclear until counters are mapped to memory, compute, synchronization, launch, or communication limits.

# %% [markdown]
# ## Read First
#
# - JAX Scaling Book: [How to Profile TPU Programs](https://jax-ml.github.io/scaling-book/profiling/)
# - NVIDIA: [CUDA C++ Best Practices Guide](https://docs.nvidia.com/cuda/cuda-c-best-practices-guide/index.html)
# - JAX Scaling Book: [All About Rooflines](https://jax-ml.github.io/scaling-book/roofline/)
# - JAX Scaling Book: [How to Think About GPUs](https://jax-ml.github.io/scaling-book/gpus/)
# - NVIDIA: [CUDA C++ Programming Guide](https://docs.nvidia.com/cuda/cuda-programming-guide/index.html)

# %% [markdown]
# ## GPUMODE Anchors
#
# - Lesson 111: [Lecture 8: CUDA Performance Checklist](https://www.youtube.com/watch?v=SGhfUhlowB4)
# - Lesson 17: [Lecture 97: HipKittens](https://www.youtube.com/watch?v=jsYyF03Fs3o)
# - Lesson 97: [Lecture 21: Scan Algorithm Part 2](https://www.youtube.com/watch?v=MH5_FeSSdIE)
# - Lesson 102: [Lecture 16: On Hands Profiling](https://www.youtube.com/watch?v=SKV6kDk1s94)
# - Lesson 115: [Lecture 4 Compute and Memory Basics](https://www.youtube.com/watch?v=lTmYrKwjSOU)

# %% [markdown]
# ## Project Tasks
#
# - `read-source-model` (reading): Read JAX Scaling Book - How to Profile TPU Programs and record the bottleneck model.
# - `anchor-gpumode-lesson` (lesson): Use GPUMODE lesson 111: Lecture 8: CUDA Performance Checklist as the concept anchor.
# - `modify-starter-source` (programming): Modify `classify_counters.py` and keep `python3 starter.py` runnable.
# - `run-local-measurement` (measurement): Run `python3 measure.py` and preserve `measurements.json`.
# - `compare-existing-lab` (comparison): Compare against `gpu-kernels-serving-lab/22-gpumode-nsight-roofline` and `22-gpumode-nsight-roofline/out_gpumode_nsight_roofline.json`.

# %%
from pathlib import Path
import json

HERE = Path.cwd()
print("project dir:", HERE)
print(json.dumps(json.loads(Path("project.json").read_text()), indent=2)[:1200])

# %%
import subprocess, sys

proc = subprocess.run([sys.executable, "starter.py"], capture_output=True, text=True)
print(proc.stdout)
print(proc.stderr)
assert proc.returncode == 0

# %%
import subprocess, sys, json
from pathlib import Path

proc = subprocess.run([sys.executable, "measure.py"], capture_output=True, text=True)
print(proc.stdout)
print(proc.stderr)
assert proc.returncode == 0
measurement = json.loads(Path("measurements.json").read_text())
assert measurement["correctness"]["status"] == "passed"
measurement

# %% [markdown]
# ## Latest Local Evidence
#
# - Status: `ran`
# - Correctness: `passed`
# - Baseline lab artifact: `22-gpumode-nsight-roofline/out_gpumode_nsight_roofline.json`
