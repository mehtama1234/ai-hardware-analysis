# %% [markdown]
# # Distributed communication: Distributed communication / collective bottleneck
#
# Query: `nccl nvshmem all reduce bandwidth topology`
#
# Suspect collective latency, bandwidth regime, topology, NCCL/NVSHMEM runtime readiness, or lack of multi-device parallelism.

# %% [markdown]
# ## Read First
#
# - JAX Scaling Book: [All About Rooflines](https://jax-ml.github.io/scaling-book/roofline/)
# - JAX Scaling Book: [How to Parallelize a Transformer for Training](https://jax-ml.github.io/scaling-book/training/)
# - Hugging Face: [Text Generation Inference Documentation](https://huggingface.co/docs/text-generation-inference/index)
# - JAX Scaling Book: [Programming TPUs in JAX](https://jax-ml.github.io/scaling-book/jax-stuff/)
# - AMD ROCm: [HIP Documentation](https://rocm.docs.amd.com/projects/HIP/en/latest/)

# %% [markdown]
# ## GPUMODE Anchors
#
# - Lesson 1: [Lecture 113: Every Microsecond Matters: Achieving Near Speed-of-Light Latency in GPU Collectives](https://www.youtube.com/watch?v=TZnJYRTSGVk)
# - Lesson 101: [Lecture 17: NCCL](https://www.youtube.com/watch?v=T22e3fgit-A)
# - Lesson 57: [Lecture 57: CuTe](https://www.youtube.com/watch?v=vzUhbDO_0qk)
# - Lesson 90: [Lecture 28: Liger Kernel - Efficient Triton Kernels for LLM Training](https://www.youtube.com/watch?v=gWble4FreV4)
# - Lesson 47: [Lecture 67: NCCL and NVSHMEM](https://www.youtube.com/watch?v=zxGVvMN6WaM)

# %% [markdown]
# ## Project Tasks
#
# - `read-source-model` (reading): Read JAX Scaling Book - All About Rooflines and record the bottleneck model.
# - `anchor-gpumode-lesson` (lesson): Use GPUMODE lesson 1: Lecture 113: Every Microsecond Matters: Achieving Near Speed-of-Light Latency in GPU Collectives as the concept anchor.
# - `modify-starter-source` (programming): Modify `collective_model.py` and keep `python3 starter.py` runnable.
# - `run-local-measurement` (measurement): Run `python3 measure.py` and preserve `measurements.json`.
# - `compare-existing-lab` (comparison): Compare against `gpu-kernels-serving-lab/26-gpumode-distributed-communication` and `26-gpumode-distributed-communication/out_gpumode_distributed_communication.json`.

# %%
from pathlib import Path
import json

HERE = Path.cwd()
print("project dir:", HERE)
print(json.dumps(json.loads(Path("project.json").read_text()), indent=2)[:1200])

# %%
import subprocess, sys

proc = subprocess.run([sys.executable, "starter.py"], capture_output=True, text=True)
print(proc.stdout)
print(proc.stderr)
assert proc.returncode == 0

# %%
import subprocess, sys, json
from pathlib import Path

proc = subprocess.run([sys.executable, "measure.py"], capture_output=True, text=True)
print(proc.stdout)
print(proc.stderr)
assert proc.returncode == 0
measurement = json.loads(Path("measurements.json").read_text())
assert measurement["correctness"]["status"] == "passed"
measurement

# %% [markdown]
# ## Latest Local Evidence
#
# - Status: `ran`
# - Correctness: `passed`
# - Baseline lab artifact: `26-gpumode-distributed-communication/out_gpumode_distributed_communication.json`
