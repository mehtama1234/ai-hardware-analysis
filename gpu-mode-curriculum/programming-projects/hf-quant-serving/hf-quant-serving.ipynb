# %% [markdown]
# # Hugging Face serving baseline: Quantization / low-precision numerics path
#
# Query: `hugging face transformers quantization tgi inference`
#
# Suspect memory savings versus numerical drift, dequantization overhead, or unsupported low-precision kernels.

# %% [markdown]
# ## Read First
#
# - Hugging Face: [Transformers Quantization](https://huggingface.co/docs/transformers/en/quantization/overview)

# %% [markdown]
# ## GPUMODE Anchors
#
# - Lesson 4: [Lecture 110: The 4-bitter lesson: Balancing Stability and Performance in NVFP4 RL](https://www.youtube.com/watch?v=wiaUh82NEoE)
# - Lesson 41: [Lecture 73: [ScaleML Series] Quantization in Large Models](https://www.youtube.com/watch?v=6Cxnnvv3DnY)
# - Lesson 12: [Lecture 102: quartet v2](https://www.youtube.com/watch?v=E0G3hf4DneA)
# - Lesson 88: [GPU MODE IRL 2024 Keynotes](https://www.youtube.com/watch?v=FH5wiwOyPX4)
# - Lesson 9: [Lecture 105: cuDNN mxfp8 attention](https://www.youtube.com/watch?v=HcnybHRbTcc)

# %% [markdown]
# ## Project Tasks
#
# - `read-source-model` (reading): Read Hugging Face - Transformers Quantization and record the bottleneck model.
# - `anchor-gpumode-lesson` (lesson): Use GPUMODE lesson 4: Lecture 110: The 4-bitter lesson: Balancing Stability and Performance in NVFP4 RL as the concept anchor.
# - `modify-starter-source` (programming): Modify `hf_baseline.py` and keep `python3 starter.py` runnable.
# - `run-local-measurement` (measurement): Run `python3 measure.py` and preserve `measurements.json`.
# - `compare-existing-lab` (comparison): Compare against `gpu-kernels-serving-lab/21-gpumode-quantized-kernels` and `21-gpumode-quantized-kernels/out_gpumode_quantized_kernels.json`.

# %%
from pathlib import Path
import json

HERE = Path.cwd()
print("project dir:", HERE)
print(json.dumps(json.loads(Path("project.json").read_text()), indent=2)[:1200])

# %%
import subprocess, sys

proc = subprocess.run([sys.executable, "starter.py"], capture_output=True, text=True)
print(proc.stdout)
print(proc.stderr)
assert proc.returncode == 0

# %%
import subprocess, sys, json
from pathlib import Path

proc = subprocess.run([sys.executable, "measure.py"], capture_output=True, text=True)
print(proc.stdout)
print(proc.stderr)
assert proc.returncode == 0
measurement = json.loads(Path("measurements.json").read_text())
assert measurement["correctness"]["status"] == "passed"
measurement

# %% [markdown]
# ## Latest Local Evidence
#
# - Status: `ran`
# - Correctness: `passed`
# - Baseline lab artifact: `21-gpumode-quantized-kernels/out_gpumode_quantized_kernels.json`
